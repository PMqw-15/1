# %%
from turtle import *

Screen().title("Эля любит меня")
#Screen().bgpic("8akreT527Jg.gif")
Screen().setup(1.0, 1.0)
colormode(255)

ht()
shape("turtle")
shapesize(0.5, 0.5)
pensize(3)
speed(0)


# Тело
color("black", (143, 133, 123))
begin_fill()
pu()
goto(-143, -35)
pd()
lt(90)
fd(187)
rt(90)
circle(800, -3.5)
circle(2, -160)
rt(180)
circle(60, 70)
goto(-144.97, 213.12)
lt(143)
circle(600, -7)
circle(150, -15)
circle(30, -10)
rt(10)
circle(300, -13)
rt(10)
circle(300, -3)
lt(150)
circle(500, 7)
circle(100, 20)
rt(10)
circle(100, 20)
lt(180)
circle(3, -200)
rt(130)
circle(150, 15)
lt(48)
fd(85)
circle(75, 70)
rt(3)
fd(75)
rt(170)
circle(27, -170)
lt(12)
bk(30)
circle(65, - 25)
lt(170)
fd(10)
circle(20, 50)
rt(160)
circle(180, -37)
rt(180)
circle(6, 130)
lt(10)
fd(50)
rt(155)
circle(20, -150)
lt(10)
circle(200, -13)
circle(25, -70)
lt(6)
bk(120)
circle(58, -32)
goto(-143, -35)
pu()
end_fill()
goto(93.57, 191.00)
pd()
rt(90)
circle(50, 30)
fd(100)
rt(180)
circle(30, -70)
rt(180)
circle(110, 25)
circle(500, 6)
goto(-143.00, 152.00)


# Уши
begin_fill()
pu()
goto(-149.44, 211.27)
pd()
lt(130)
circle(85, -60)
rt(90)
circle(300, -12.5)
pensize(1)
goto(-149.44, 211.27)
pensize(3)
pu()
goto(30, 285)
pd()
lt(70)
circle(150, -27)
rt(90)
circle(300, -15)
rt(100)
pensize(2)
circle(120, -42)
pensize(3)
end_fill()

# Хвост
color("black", (129, 108, 86))
pu()
goto(-143, -21)
pd()
begin_fill()
rt(110)
circle(180, 65)
circle(105, 80)
rt(180)
circle(800, -7)
rt(69)
circle(500, 10)
circle(30, 40)
rt(180)
circle(500, -10)
circle(46, -100)
bk(33)
lt(100)
circle(80, -32)
end_fill()


# Живот и лицо
color((231, 222, 207))
pu()
goto(92, -48)
pd()
begin_fill()
rt(170)
circle(200, 35)
circle(73, 170)
circle(600, 7)
lt(50)
pencolor("black")
circle(210, 36)
color((231, 222, 207))
end_fill()


exitonclick()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-91d008c151ce> in <cell line: 0>()
#       1 from turtle import *
#       2
# ----> 3 Screen().title("Эля любит меня")
#       4 #Screen().bgpic("8akreT527Jg.gif")
#       5 Screen().setup(1.0, 1.0)
#
# /usr/lib/python3.11/turtle.py in Screen()
#    3678     else return the existing one."""
#    3679     if Turtle._screen is None:
# -> 3680         Turtle._screen = _Screen()
#    3681     return Turtle._screen
#    3682
#
# /usr/lib/python3.11/turtle.py in __init__(self)
#    3694         # preserved (perhaps by passing it as an optional parameter)
#    3695         if _Screen._root is None:
# -> 3696             _Screen._root = self._root = _Root()
#    3697             self._root.title(_Screen._title)
#    3698             self._root.ondestroy(self._destroy)
#
# /usr/lib/python3.11/turtle.py in __init__(self)
# ...
